# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosen-tech/NA3A-programmering/blob/main/08_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
name = input("Skriv ditt namn: ")
print("Hej,"+ name)
# Out:
# Hello world
# Skriv ditt namn: Max
# Hej,Max
